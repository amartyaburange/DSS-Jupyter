# %% [markdown]
# # Practical No. 3

# %% [markdown]
# ### Aim: Creating the Dataframe

# %%
#Name:Rudraksh K. Ramekar
#Roll no.:69
#Subject:ET1
#Sec:C
#Date:25/08/2025

# %% [markdown]
# # Creating series

# %%
import pandas as pd

# %%
Name=["rudrx","dev","vedant","amartya","pratik"]

# %%
Name
# Out:
# ['rudrx', 'dev', 'vedant', 'amartya', 'pratik']

# %%
Roll_list=pd.Series(Name,index=[1,2,3,4,5])
print(Roll_list)
# Out:
# 1      rudrx
# 2        dev
# 3     vedant
# 4    amartya
# 5     pratik
# dtype: object

# %% [markdown]
# # Creating DataFrame

# %%
df=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],
               columns=["CD","DBMS","DSS","CAO"])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Adding Record (Row)to the data frame

# %%
df2=pd.DataFrame([[10,12,14,16]],
columns=["CD","DBMS","DSS","CAO"])

# %%
df3=pd.concat([df,df2], ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15
# 3  10    12   14   16

# %% [markdown]
# # Deleting Record from df3 dataframe

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 2  12    13   14   15
# 3  10    12   14   16

# %% [markdown]
# # Adding Attribute (columns)to data frame

# %%
df3["DM"]=[11,22,33,44]

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  11
# 1  11    18   15   21  22
# 2  12    13   14   15  33
# 3  10    12   14   16  44

# %% [markdown]
# # Deleting attribut (columns) from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15
# 3  10    12   14   16

# %%
print("mean of dss:",df5["DSS"].mean())
# Out:
# mean of dss: 14.25

# %%
print("median of dss:",df5["DSS"].median())
# Out:
# median of dss: 14.0

# %%
print("mode of dss:",df5["DSS"].mode())
# Out:
# mode of dss: 0    14
# Name: DSS, dtype: int64
